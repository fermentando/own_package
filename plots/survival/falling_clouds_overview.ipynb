# %%
from falling_cloud_v2 import FallingCloud
#from cooling import load_cooling_table

#load_cooling_table('/viper/ptmp/ferhi/cooling_tables/gnat-sternberg.cooling_1Z')
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
import traceback

try:
    fc = FallingCloud(d0=20., r_cl0=100.)
except Exception as e:
    traceback.print_exc()
fc.integrate(4, stop_mode='height')
# fc.integrate(150)
fc.plot_trajectory()
# Out:
# A termination event occurred.

# %%
from cooling import get_t_cool_cgs as tcool
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from cooling import get_t_cool_cgs as tcool
#
# File ~/own_package/athenapk/cooling.py:10
#       8 from scipy.optimize import minimize_scalar
#       9 import matplotlib.pyplot as plt
# ---> 10 import utils as ut
#      11 import astropy.constants as C
#      13 # Global cooling table variables
#
# File ~/own_package/athenapk/utils.py:7
#       5 import matplotlib.pyplot as plt
#       6 import matplotlib.style as style
# ----> 7 import yt
#       8 from yt.units import dyn, cm, K
#       9 import os
#
# File ~/.local/lib/python3.12/site-packages/yt/__init__.py:14
#      12 import yt.units as units
#      13 import yt.utilities.physical_constants as physical_constants
# ---> 14 from yt.data_objects.api import (
#      15     DatasetSeries,
#      16     ImageArray,
#      17     ParticleProfile,
# ...

# %%
tcool(1e-23, 1e4, 0.6e-27)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tcool(1e-23, 1e4, 0.6e-27)
#
# File ~/own_package/athenapk/cooling.py:101, in get_t_cool_cgs(rho, T, mbar_val, gamma)
#      98     mbar_val = mbar
#     100 e = ut.constants.kb * T / (gamma - 1) / mbar_val
# --> 101 log_lambda = np.interp(np.log10(T), cooling_table_logT_cgs, cooling_table_logLambda_cgs)
#     102 Lambda = 10**log_lambda
#     103 n_H = rho / mbar_val
#
# File ~/Packages/miniforge3/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:1642, in interp(x, xp, fp, left, right, period)
#    1639     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1640     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1642 return interp_func(x, xp, fp, left, right)
#
# ValueError: object of too small depth for desired array
